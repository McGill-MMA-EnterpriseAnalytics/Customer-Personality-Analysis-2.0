# %% [markdown]
# # Setup local hosted mlflow ui

# %%
# pip install --upgrade mlflow

# %%
# !pip install mlflow

# %%
# !mlflow ui
# Out:
# [2024-04-24 19:33:08 -0400] [12519] [INFO] Starting gunicorn 21.2.0
# [2024-04-24 19:33:08 -0400] [12519] [INFO] Listening at: http://127.0.0.1:5000 (12519)
# [2024-04-24 19:33:08 -0400] [12519] [INFO] Using worker: sync
# [2024-04-24 19:33:08 -0400] [12520] [INFO] Booting worker with pid: 12520
# [2024-04-24 19:33:08 -0400] [12521] [INFO] Booting worker with pid: 12521
# [2024-04-24 19:33:08 -0400] [12522] [INFO] Booting worker with pid: 12522
# [2024-04-24 19:33:08 -0400] [12523] [INFO] Booting worker with pid: 12523
# ...
# [2024-04-24 20:30:31 -0400] [12519] [CRITICAL] WORKER TIMEOUT (pid:12520)
# [2024-04-24 20:30:31 -0400] [12519] [CRITICAL] WORKER TIMEOUT (pid:12521)
# [2024-04-24 20:30:31 -0400] [12519] [CRITICAL] WORKER TIMEOUT (pid:12522)
# [2024-04-24 20:30:31 -0400] [12519] [CRITICAL] WORKER TIMEOUT (pid:12523)
# [2024-04-24 20:30:31 -0400] [12521] [INFO] Worker exiting (pid: 12521)
# [2024-04-24 20:30:31 -0400] [12520] [INFO] Worker exiting (pid: 12520)
# ...
