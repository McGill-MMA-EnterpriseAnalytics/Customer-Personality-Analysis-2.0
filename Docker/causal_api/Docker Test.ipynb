# %% [markdown]
# # Docker Setup and Pull mlflow

# %%
# Get the app
# !git clone https://github.com/docker/getting-started-app.git

# %%
# Build the app's image
# !cd /Users/kellyliu/Documents/GitHub/Customer-Personality-Analysis-2.0/Docker/prediction_api

# %%
# Create an empty file named Dockerfile.
# !touch Dockerfile

# %%
# make sure in the getting-started-app directory
# !cd prediction_api
# Out:
# zsh:cd:1: no such file or directory: getting-started-app

# %%
# !ls -al
# Out:
# total 448
# drwxr-xr-x  8 kellyliu  staff     256 Apr 26 02:21 .
# drwxr-xr-x  5 kellyliu  staff     160 Apr 25 21:05 ..
# -rw-r--r--@ 1 kellyliu  staff    6148 Apr 25 19:13 .DS_Store
# -rw-r--r--  1 kellyliu  staff  211470 Apr 26 02:23 Docker Test.ipynb
# -rw-r--r--  1 kellyliu  staff     561 Apr 25 23:55 Dockerfile
# drwxr-xr-x  5 kellyliu  staff     160 Apr 25 19:19 app
# drwxr-xr-x  3 kellyliu  staff      96 Apr 26 02:18 model
# -rw-r--r--  1 kellyliu  staff      70 Apr 25 23:59 requirements.txt

# %%
# Build the app's image
# !docker build -t prediction_api .
# Out:
# [+] Building 0.0s (0/0)  docker:desktop-linux
# [+] Building 0.0s (0/1)                                    docker:desktop-linux
# [+] Building 0.2s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 600B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.2s
# [+] Building 0.3s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 600B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.3s
# [+] Building 0.4s (2/2)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
# ...

# %%
# Start an app container
# !docker run -dp 127.0.0.1:8000:8000 prediction_api
# Out:
# 93324b1cb33dd5efd2e338dfb2f26d5a2cf2812e801dac5840613bf79e831a3d

# %%
# Check if the Container is running
# !docker ps
# Out:
# CONTAINER ID   IMAGE            COMMAND                  CREATED         STATUS         PORTS                                NAMES
# 93324b1cb33d   prediction_api   "uvicorn app.predict…"   3 seconds ago   Up 2 seconds   127.0.0.1:8000->8000/tcp             brave_morse
# 30c5f32ff306   prediction_api   "uvicorn app.predict…"   2 minutes ago   Up 2 minutes   127.0.0.1:3000->3000/tcp, 8000/tcp   pedantic_chatelet

# %%
# !docker pull ghcr.io/mlflow/mlflow:v2.12.1
# Out:
# v2.12.1: Pulling from mlflow/mlflow
# Digest: sha256:00fd66fe10c93315eb6a5e98f872bc237aed03b5010cdc145b82b01ab1a4cf92
# Status: Image is up to date for ghcr.io/mlflow/mlflow:v2.12.1
# ghcr.io/mlflow/mlflow:v2.12.1
#
# What's Next?
#   View a summary of image vulnerabilities and recommendations → docker scout quickview ghcr.io/mlflow/mlflow:v2.12.1
